# %%
import pandas as pd

# %%
data = pd.read_csv('strava_activity.csv')

# %%
data_males = data[data['athlete.sex'] == "M"]
data_females = data[data['athlete.sex'] == "F"]

# %%
data_males
# Out:
#       achievement_count  athlete.badge_type_id            athlete.city  \
# 1                     0                      0              Oisterwijk
# 2                     8                      0               Ypsilanti
# 5                     0                      0                 Cardiff
# 6                     0                      0                Šiauliai
# 10                    5                      1           West Kilbride
# 14                    2                      0              Gold Coast
# 15                    8                      0                  Huelva
# 16                    0                      0                   Perth
# 17                    0                      0               Faversham
# 18                    8                      0                 Bendigo
# 19                    0                      0                  Ogden
# 20                    1                      0                 Madison
# ...
